# %% [markdown]
# Se cargan las librerías necesarias para el proceso.

# %%
import pandas as pd

# %%
# Se carga la base de datos

datos = pd.read_csv('/Users/michelcano/Documents/Public_Versions_Codes/eda_nuevo_laredo/iter_28_cpv2020/conjunto_de_datos/conjunto_de_datos_iter_28CSV20.csv', encoding='UTF-8')

# %%
datos = datos[datos['NOM_MUN'] == 'Nuevo Laredo']

# %%
datos
# Out:
#       ENTIDAD     NOM_ENT  MUN       NOM_MUN   LOC  \
# 3934       28  Tamaulipas   27  Nuevo Laredo     0
# 3935       28  Tamaulipas   27  Nuevo Laredo     1
# 3936       28  Tamaulipas   27  Nuevo Laredo   103
# 3937       28  Tamaulipas   27  Nuevo Laredo   105
# 3938       28  Tamaulipas   27  Nuevo Laredo   108
# 3939       28  Tamaulipas   27  Nuevo Laredo   111
# 3940       28  Tamaulipas   27  Nuevo Laredo   113
# 3941       28  Tamaulipas   27  Nuevo Laredo   120
# 3942       28  Tamaulipas   27  Nuevo Laredo   156
# 3943       28  Tamaulipas   27  Nuevo Laredo   162
# 3944       28  Tamaulipas   27  Nuevo Laredo   191
# 3945       28  Tamaulipas   27  Nuevo Laredo   195
# 3946       28  Tamaulipas   27  Nuevo Laredo   199
# 3947       28  Tamaulipas   27  Nuevo Laredo   203
# 3948       28  Tamaulipas   27  Nuevo Laredo   205
# 3949       28  Tamaulipas   27  Nuevo Laredo   222
# 3950       28  Tamaulipas   27  Nuevo Laredo   227
# ...
